# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

import pandas as pd
import numpy as np
import seaborn as sns

from hdfs import InsecureClient

# %%
from matplotlib import rc
plt.rc('font', family="NanumBarunGothic")
plt.text(0.2,0.4,'한글',size=100)
# Out:
# Text(0.2, 0.4, '한글')

# %%
data = pd.read_excel("부산_전체_주유소_통합.xlsx")
data
# Out:
#         지역                 상호                      주소        상표  \
# 0    부산광역시              해안주유소         부산 강서구 낙동남로 432     SK에너지
# 1    부산광역시   신창에너지㈜직영 송정셀프주유소   부산 강서구 낙동남로 127 (송정동)     S-OIL
# 2    부산광역시        은마석유 경기장주유소         부산 강서구 낙동북로 364     GS칼텍스
# 3    부산광역시      동방석유㈜직영 대저주유소  부산 강서구 낙동북로 209 (대저1동)     SK에너지
# 4    부산광역시             우리2주유소         부산 강서구 낙동북로 142     알뜰주유소
# ..     ...                ...                     ...       ...
# 342  부산광역시              대림주유소        부산 사상구 낙동대로 1320     S-OIL
# 343  부산광역시  광신홀딩스㈜ 직영 낙동대로주유소         부산 사상구 낙동대로 935     SK에너지
# 344  부산광역시           행복한셀프주유소    부산 사상구 학감대로 73 (학장동)  HD현대오일뱅크
# 345  부산광역시     지에스칼텍스(주)서부주유소        부산 사상구 낙동대로 1380     GS칼텍스
# 346  부산광역시           아시아사상주유소    부산 사상구 새벽로 207 (괘법동)     SK에너지
#
#               전화번호 셀프여부 고급휘발유   휘발유    경유  실내등유
# 0    070-8894-3569    Y     -  1549  1399     -
# 1     051-972-5104    Y     -  1549  1409     -
# 2     051-971-7956    Y  1898  1557  1417  1300
# 3     051-971-2135    Y     -  1557  1417     -
# 4     051-971-5585    Y     -  1557  1417     -
# ..             ...  ...   ...   ...   ...   ...
# 342   051-302-1577    Y  1959  1679  1549  1450
# 343   051-311-0131    Y     -  1689  1544     -
# 344   051-327-7547    Y     -  1689  1549     -
# 345   051-304-8873    Y  1983  1739  1599  1500
# 346   051-321-1445    N     -  1797  1687  1600
#
# [347 rows x 10 columns]

# %%
import numpy as np
data.replace('-', np.nan, inplace=True)

# %%
data
# Out:
#         지역                 상호                      주소        상표  \
# 0    부산광역시              해안주유소         부산 강서구 낙동남로 432     SK에너지
# 1    부산광역시   신창에너지㈜직영 송정셀프주유소   부산 강서구 낙동남로 127 (송정동)     S-OIL
# 2    부산광역시        은마석유 경기장주유소         부산 강서구 낙동북로 364     GS칼텍스
# 3    부산광역시      동방석유㈜직영 대저주유소  부산 강서구 낙동북로 209 (대저1동)     SK에너지
# 4    부산광역시             우리2주유소         부산 강서구 낙동북로 142     알뜰주유소
# ..     ...                ...                     ...       ...
# 342  부산광역시              대림주유소        부산 사상구 낙동대로 1320     S-OIL
# 343  부산광역시  광신홀딩스㈜ 직영 낙동대로주유소         부산 사상구 낙동대로 935     SK에너지
# 344  부산광역시           행복한셀프주유소    부산 사상구 학감대로 73 (학장동)  HD현대오일뱅크
# 345  부산광역시     지에스칼텍스(주)서부주유소        부산 사상구 낙동대로 1380     GS칼텍스
# 346  부산광역시           아시아사상주유소    부산 사상구 새벽로 207 (괘법동)     SK에너지
#
#               전화번호 셀프여부 고급휘발유   휘발유    경유  실내등유
# 0    070-8894-3569    Y   NaN  1549  1399   NaN
# 1     051-972-5104    Y   NaN  1549  1409   NaN
# 2     051-971-7956    Y  1898  1557  1417  1300
# 3     051-971-2135    Y   NaN  1557  1417   NaN
# 4     051-971-5585    Y   NaN  1557  1417   NaN
# ..             ...  ...   ...   ...   ...   ...
# 342   051-302-1577    Y  1959  1679  1549  1450
# 343   051-311-0131    Y   NaN  1689  1544   NaN
# 344   051-327-7547    Y   NaN  1689  1549   NaN
# 345   051-304-8873    Y  1983  1739  1599  1500
# 346   051-321-1445    N   NaN  1797  1687  1600
#
# [347 rows x 10 columns]

# %%
data.to_csv("부산_전체_주유소_통합.csv", index=False, encoding='utf-8-sig')

# %%
lst = []
for i in data['주소'] :
    lst.append(i.split(' ')[1])

# %%
data['구'] = lst

# %%
data
# Out:
#         지역                 상호                      주소        상표  \
# 0    부산광역시              해안주유소         부산 강서구 낙동남로 432     SK에너지
# 1    부산광역시   신창에너지㈜직영 송정셀프주유소   부산 강서구 낙동남로 127 (송정동)     S-OIL
# 2    부산광역시        은마석유 경기장주유소         부산 강서구 낙동북로 364     GS칼텍스
# 3    부산광역시      동방석유㈜직영 대저주유소  부산 강서구 낙동북로 209 (대저1동)     SK에너지
# 4    부산광역시             우리2주유소         부산 강서구 낙동북로 142     알뜰주유소
# ..     ...                ...                     ...       ...
# 342  부산광역시              대림주유소        부산 사상구 낙동대로 1320     S-OIL
# 343  부산광역시  광신홀딩스㈜ 직영 낙동대로주유소         부산 사상구 낙동대로 935     SK에너지
# 344  부산광역시           행복한셀프주유소    부산 사상구 학감대로 73 (학장동)  HD현대오일뱅크
# 345  부산광역시     지에스칼텍스(주)서부주유소        부산 사상구 낙동대로 1380     GS칼텍스
# 346  부산광역시           아시아사상주유소    부산 사상구 새벽로 207 (괘법동)     SK에너지
#
#               전화번호 셀프여부 고급휘발유   휘발유    경유  실내등유    구
# 0    070-8894-3569    Y   NaN  1549  1399   NaN  강서구
# 1     051-972-5104    Y   NaN  1549  1409   NaN  강서구
# 2     051-971-7956    Y  1898  1557  1417  1300  강서구
# 3     051-971-2135    Y   NaN  1557  1417   NaN  강서구
# 4     051-971-5585    Y   NaN  1557  1417   NaN  강서구
# ..             ...  ...   ...   ...   ...   ...  ...
# 342   051-302-1577    Y  1959  1679  1549  1450  사상구
# 343   051-311-0131    Y   NaN  1689  1544   NaN  사상구
# 344   051-327-7547    Y   NaN  1689  1549   NaN  사상구
# 345   051-304-8873    Y  1983  1739  1599  1500  사상구
# 346   051-321-1445    N   NaN  1797  1687  1600  사상구
#
# [347 rows x 11 columns]

# %%
df = data[['구', '주소', '상호', '휘발유', '경유']]

# %%
df
# Out:
#        구                      주소                 상호   휘발유    경유
# 0    강서구         부산 강서구 낙동남로 432              해안주유소  1549  1399
# 1    강서구   부산 강서구 낙동남로 127 (송정동)   신창에너지㈜직영 송정셀프주유소  1549  1409
# 2    강서구         부산 강서구 낙동북로 364        은마석유 경기장주유소  1557  1417
# 3    강서구  부산 강서구 낙동북로 209 (대저1동)      동방석유㈜직영 대저주유소  1557  1417
# 4    강서구         부산 강서구 낙동북로 142             우리2주유소  1557  1417
# ..   ...                     ...                ...   ...   ...
# 342  사상구        부산 사상구 낙동대로 1320              대림주유소  1679  1549
# 343  사상구         부산 사상구 낙동대로 935  광신홀딩스㈜ 직영 낙동대로주유소  1689  1544
# 344  사상구    부산 사상구 학감대로 73 (학장동)           행복한셀프주유소  1689  1549
# 345  사상구        부산 사상구 낙동대로 1380     지에스칼텍스(주)서부주유소  1739  1599
# 346  사상구    부산 사상구 새벽로 207 (괘법동)           아시아사상주유소  1797  1687
#
# [347 rows x 5 columns]

# %%
import pandas as pd
df1 = pd.read_csv('부산_전체_주유소_수정.csv')

# %%
c_data = df1.sort_values('휘발유', ascending=True).head(5)
e_data = df1.sort_values('휘발유', ascending=False).head(5)

# %%
c_data1 = df1.sort_values('경유', ascending=True).head(5)
e_data1 = df1.sort_values('경유', ascending=False).head(5)

# %%
e_data
# Out:
#        구                      주소               상호     휘발유      경유         위도  \
# 251   동구    부산 동구 중앙대로 168 (초량동)      ㈜삼현석유 천일주유소  1998.0  1698.0  35.112306
# 50   강서구       부산 강서구 르노삼성대로 372  광신석유(주)직영 명지주유소  1899.0  1897.0  35.089356
# 86    서구           부산 서구 감천로 227       피치스주유소 송도점  1888.0  1408.0  35.082180
# 85    서구           부산 서구 원양로 260    ㈜한국페트로 스타2주유소  1868.0  1434.0  35.074278
# 122  영도구  부산 영도구 태종로 181 (봉래동4가)   (주)나부코직영 우원주유소  1848.0  1738.0  35.091292
#
#              경도
# 251  129.038789
# 50   128.897599
# 86   129.012595
# 85   129.006493
# 122  129.049336

# %%
c_data
# Out:
#        구                     주소                 상호     휘발유      경유         위도  \
# 252  동래구         부산 동래구 충렬대로 95  광신석유(주)직영 충렬대로주유소  1489.0  1349.0  35.207439
# 253  동래구  부산 동래구 충렬대로 121 (온천동)       동방석유(주)푸른주유소  1499.0  1344.0  35.206432
# 255  동래구         부산 동래구 반송로 245       ㈜OS에너지 동호주유소  1499.0  1349.0  35.202602
# 254  동래구        부산 동래구 충렬대로 124              대일주유소  1499.0  1349.0  35.205857
# 256  동래구   부산 동래구 반송로 303 (명장동)              명장주유소  1499.0  1349.0  35.206779
#
#              경도
# 252  129.071591
# 253  129.073920
# 255  129.098964
# 254  129.073877
# 256  129.102708

# %%
c_data1
# Out:
#        구                     주소                 상호     휘발유      경유         위도  \
# 253  동래구  부산 동래구 충렬대로 121 (온천동)       동방석유(주)푸른주유소  1499.0  1344.0  35.206432
# 252  동래구         부산 동래구 충렬대로 95  광신석유(주)직영 충렬대로주유소  1489.0  1349.0  35.207439
# 254  동래구        부산 동래구 충렬대로 124              대일주유소  1499.0  1349.0  35.205857
# 255  동래구         부산 동래구 반송로 245       ㈜OS에너지 동호주유소  1499.0  1349.0  35.202602
# 256  동래구   부산 동래구 반송로 303 (명장동)              명장주유소  1499.0  1349.0  35.206779
#
#              경도
# 253  129.073920
# 252  129.071591
# 254  129.073877
# 255  129.098964
# 256  129.102708

# %%
e_data1
# Out:
#         구                      주소               상호     휘발유      경유         위도  \
# 50    강서구       부산 강서구 르노삼성대로 372  광신석유(주)직영 명지주유소  1899.0  1897.0  35.089356
# 122   영도구  부산 영도구 태종로 181 (봉래동4가)   (주)나부코직영 우원주유소  1848.0  1738.0  35.091292
# 121   영도구   부산 영도구 남항서로 96(남항동2가)            남항주유소  1833.0  1723.0  35.089025
# 288  부산진구  부산 부산진구 가야대로 523 (가야동)            대명주유소  1838.0  1718.0  35.153940
# 98    수영구          부산 수영구 연수로 411    SK에너지(주)강일주유소  1798.0  1698.0  35.168301
#
#              경도
# 50   128.897599
# 122  129.049336
# 121  129.036467
# 288  129.029220
# 98   129.114322

# %%
import folium

m = folium.Map(location=[35.1796, 129.0756], zoom_start=12)

for _, row in c_data.iterrows():
    popup_html = f"""
    <div style="font-size:13px;">
        <b>{row['상호']}</b><br>
        휘발유: {int(row['휘발유'])}원
    </div>
    """
    folium.Marker(
        location=[row['위도'], row['경도']],
        popup=folium.Popup(popup_html, max_width=200),
        icon=folium.Icon(color='blue')
    ).add_to(m)

for _, row in e_data.iterrows():
    popup_html = f"""
    <div style="font-size:13px;">
        <b>{row['상호']}</b><br>
        휘발유: {int(row['휘발유'])}원
    </div>
    """
    folium.Marker(
        location=[row['위도'], row['경도']],
        popup=folium.Popup(popup_html, max_width=200),
        icon=folium.Icon(color='red')
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e433662d5067c7203d4c559be51670c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e433662d5067c7203d4c559be51670c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e433662d5067c7203d4c559be51670c3 = L.map(
#                 &quot;map_e433662d5067c7203d4c559be51670c3&quot;,
#                 {
#                     center: [35.1796, 129.0756],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_608339dc0aa3523bdbecb21a61f96b5a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_608339dc0aa3523bdbecb21a61f96b5a.addTo(map_e433662d5067c7203d4c559be51670c3);
#
#
#             var marker_de0dec21311415d43fa22cb1157e12a8 = L.marker(
#                 [35.2074394, 129.0715907],
#                 {
# }
#             ).addTo(map_e433662d5067c7203d4c559be51670c3);
#
#
#             var icon_95ec6d1f9d68ba9a1e39f961e8dbc666 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4f55ac3cbee3ae35264a005e52504ab0 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_4fcf0270ee707129e663b3782bcbdc63 = $(`&lt;div id=&quot;html_4fcf0270ee707129e663b3782bcbdc63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;div style=&quot;font-size:13px;&quot;&gt;         &lt;b&gt;광신석유(주)직영 충렬대로주유소&lt;/b&gt;&lt;br&gt;         휘발유: 1489원     &lt;/div&gt;     &lt;/div&gt;`)[0];
#                 popup_4f55ac3cbee3ae35264a005e52504ab0.setContent(html_4fcf0270ee707129e663b3782bcbdc63);
#
#
#
#         marker_de0dec21311415d43fa22cb1157e12a8.bindPopup(popup_4f55ac3cbee3ae35264a005e52504ab0)
#         ;
#
#
#
#
#                 marker_de0dec21311415d43fa22cb1157e12a8.setIcon(icon_95ec6d1f9d68ba9a1e39f961e8dbc666);
#
#
#             var marker_f4981630a1aecc92c792523578908774 = L.marker(
#                 [35.2064321, 129.0739197],
#                 {
# }
#             ).addTo(map_e433662d5067c7203d4c559be51670c3);
#
#
#             var icon_68bb2bf36694188f521741545fbdcd7c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_79905788ff1aee78d53eeaf025117ac5 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_c89bd8000e511104b9e2a61d20db44c5 = $(`&lt;div id=&quot;html_c89bd8000e511104b9e2a61d20db44c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;div style=&quot;font-size:13px;&quot;&gt;         &lt;b&gt;동방석유(주)푸른주유소&lt;/b&gt;&lt;br&gt;         휘발유: 1499원     &lt;/div&gt;     &lt;/div&gt;`)[0];
#                 popup_79905788ff1aee78d53eeaf025117ac5.setContent(html_c89bd8000e511104b9e2a61d20db44c5);
#
#
#
#         marker_f4981630a1aecc92c792523578908774.bindPopup(popup_79905788ff1aee78d53eeaf025117ac5)
#         ;
#
#
#
#
#                 marker_f4981630a1aecc92c792523578908774.setIcon(icon_68bb2bf36694188f521741545fbdcd7c);
#
#
#             var marker_6ea4652168ed8ed33d18cbdbbc5cad1f = L.marker(
#                 [35.2026025, 129.0989642],
#                 {
# }
#             ).addTo(map_e433662d5067c7203d4c559be51670c3);
#
#
#             var icon_f317a646cc25a9d3847018d9e67d5def = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_98a79217fbec7fd9d13c4d4aa2d413f3 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_07af43dfded57056f6a6b66507b63561 = $(`&lt;div id=&quot;html_07af43dfded57056f6a6b66507b63561&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;div style=&quot;font-size:13px;&quot;&gt;         &lt;b&gt;㈜OS에너지 동호주유소&lt;/b&gt;&lt;br&gt;         휘발유: 1499원     &lt;/div&gt;     &lt;/div&gt;`)[0];
#                 popup_98a79217fbec7fd9d13c4d4aa2d413f3.setContent(html_07af43dfded57056f6a6b66507b63561);
#
#
#
#         marker_6ea4652168ed8ed33d18cbdbbc5cad1f.bindPopup(popup_98a79217fbec7fd9d13c4d4aa2d413f3)
#         ;
#
#
#
#
#                 marker_6ea4652168ed8ed33d18cb
