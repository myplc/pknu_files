# %%
import os
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC


driver = webdriver.Chrome()
driver.get("https://www.opinet.co.kr/user/main/mainView.do")
wait = WebDriverWait(driver, 10)

# (1) hover 대상: "싼 주유소 찾기"
hover_element = wait.until(EC.presence_of_element_located(
    (By.CSS_SELECTOR, "#header > div > ul > li:nth-child(1) > a")
))

# (2) hover 동작 수행
ActionChains(driver).move_to_element(hover_element).perform()

# (3) hover 후 서브 메뉴 "경로별" 나타나므로 기다렸다가 클릭
menu_option = wait.until(EC.element_to_be_clickable(
    (By.CSS_SELECTOR, "#header > div > ul > li:nth-child(1) > ul > li:nth-child(1) > a > span")
))
menu_option.click()

# 시/도 선택
city = wait.until(EC.presence_of_element_located((By.ID, "SIDO_NM0")))
select_city = Select(city)
select_city.select_by_visible_text("부산")
time.sleep(1)

for i in range(0,16):
    # 구/군 선택
    gu = wait.until(EC.presence_of_element_located((By.ID, "SIGUNGU_NM0")))
    select_gu = Select(gu)
    time.sleep(1)
    
    # 구 목록 출력 및 선택
    gu_list = [option.get_attribute("value") for option in gu.find_elements(By.TAG_NAME, "option") if option.get_attribute("value")]
    select_gu.select_by_visible_text(gu_list[i])  #구 선택
    time.sleep(1)

    excel = wait.until(EC.element_to_be_clickable(
        (By.CSS_SELECTOR, "#templ_list0 > div:nth-child(7) > div > a > span")
    ))
    excel.click()


driver.quit()

# %%
# !pip install openpyxl

# %%
from io import BytesIO
from hdfs import InsecureClient
import pandas as pd

# HDFS 연결
hdfs = InsecureClient("http://namenode:9870", user="hadoop")

# 파일 경로 리스트
paths = [f"지역_위치별(주유소) ({i}).xls" for i in range(1, 16)]
paths.insert(0, "지역_위치별(주유소).xls")

# 파일 읽고 리스트에 저장
datas = []
for path in paths:
    with hdfs.read(path) as reader:
        bytes_data = reader.read()
        bio = BytesIO(bytes_data)
        df = pd.read_excel(bio)
        datas.append(df)

# 병합
df = pd.concat(datas, ignore_index=True)
# Out:
# --- DataFrame 0 ---
#   지역_위치별(주유소)        Unnamed: 1             Unnamed: 2 Unnamed: 3  \
# 0         NaN               NaN                    NaN        NaN
# 1          지역                상호                     주소         상표
# 2       부산광역시             해안주유소        부산 강서구 낙동남로 432      SK에너지
# 3       부산광역시  신창에너지㈜직영 송정셀프주유소  부산 강서구 낙동남로 127 (송정동)      S-OIL
# 4       부산광역시             서강주유소   부산 강서구 낙동북로 42 (강동동)      SK에너지
#
#       Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8   Unnamed: 9
# 0            NaN        NaN        NaN        NaN        NaN  (단위 : 원/리터)
# 1           전화번호       셀프여부      고급휘발유        휘발유         경유         실내등유
# 2  070-8894-3569          Y          -       1549       1399            -
# 3   051-972-5104          Y          -       1549       1409            -
# 4   051-971-8484          Y          -       1557       1417            -
#
# --- DataFrame 1 ---
#   지역_위치별(주유소)       Unnamed: 1              Unnamed: 2 Unnamed: 3  \
# 0         NaN              NaN                     NaN        NaN
# 1          지역               상호                      주소         상표
# 2       부산광역시  한길주유소 금사점 한솔유화㈜    부산 금정구 반송로 420 (금사동)   HD현대오일뱅크
# 3       부산광역시         훼미리알뜰주유소            부산 금정구 두실로 2      알뜰주유소
# 4       부산광역시       은마석유 노포주유소  부산 금정구 중앙대로 2191 (노포동)      GS칼텍스
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8   Unnamed: 9
# 0           NaN        NaN        NaN        NaN        NaN  (단위 : 원/리터)
# 1          전화번호       셀프여부      고급휘발유        휘발유         경유         실내등유
# 2  051-524-6642          Y       1897       1549       1419            -
# 3  051-582-5882          Y          -       1575       1437            -
# 4  051-508-1645          Y       1849       1575       1437         1350
#
# --- DataFrame 2 ---
#   지역_위치별(주유소)           Unnamed: 1              Unnamed: 2 Unnamed: 3  \
# 0         NaN                  NaN                     NaN        NaN
# 1          지역                   상호                      주소         상표
# 2       부산광역시  기장대로 셀프주유소 와이케이에너지㈜     부산 기장군 기장읍 기장대로 343      GS칼텍스
# 3       부산광역시   신아시아드주유소/충전소 은마석유㈜  부산광역시 기장군 일광면 기장대로 996      GS칼텍스
# 4       부산광역시                내리주유소      부산 기장군 기장읍 기장대로 84   HD현대오일뱅크
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8   Unnamed: 9
# 0           NaN        NaN        NaN        NaN        NaN  (단위 : 원/리터)
# 1          전화번호       셀프여부      고급휘발유        휘발유         경유         실내등유
# 2  051-723-5189          Y       1839       1519       1374            -
# 3  051-722-8701          Y       1839       1519       1374            -
# 4  051-722-7363          Y          -       1529       1395         1350
#
# --- DataFrame 3 ---
#   지역_위치별(주유소)   Unnamed: 1              Unnamed: 2 Unnamed: 3    Unnamed: 4  \
# 0         NaN          NaN                     NaN        NaN           NaN
# 1          지역           상호                      주소         상표          전화번호
# 2       부산광역시  내트럭(주)부산사업소           부산 남구 신선로 168      SK에너지  051-638-3971
# 3       부산광역시        대일주유소  부산 남구 황령대로 401-2 (대연동)      GS칼텍스  051-627-0727
# 4       부산광역시   내트럭(주)부산용당           부산 남구 신선로 261      SK에너지  051-931-8001
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8   Unnamed: 9
# 0        NaN        NaN        NaN        NaN  (단위 : 원/리터)
# 1       셀프여부      고급휘발유        휘발유         경유         실내등유
# 2          N          -       1563       1499            -
# 3          Y       1813       1563       1433            -
# 4          N          -       1563       1499            -
#
# --- DataFrame 4 ---
#   지역_위치별(주유소)     Unnamed: 1            Unnamed: 2 Unnamed: 3    Unnamed: 4  \
# 0         NaN            NaN                   NaN        NaN           NaN
# 1          지역             상호                    주소         상표          전화번호
# 2       부산광역시  CJ대한통운㈜ 부산주유소  부산 동구 충장대로 305 (좌천동)      GS칼텍스  051-719-5143
# 3       부산광역시  부산벙커앤오일 청구주유소  부산 동구 충장대로 281 (좌천동)      SK에너지  051-635-9698
# 4       부산광역시  (주)대양씨앤씨직영주유소    부산 동구 성남로 74 (범일동)      GS칼텍스  051-646-5563
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8   Unnamed: 9
# 0        NaN        NaN        NaN        NaN  (단위 : 원/리터)
# 1       셀프여부      고급휘발유        휘발유         경유         실내등유
# 2          Y       1825       1580       1445            -
# 3          Y          -       1580       1445         1500
# 4          Y          -       1583       1445            -
#
# --- DataFrame 5 ---
#   지역_위치별(주유소)         Unnamed: 1       Unnamed: 2 Unnamed: 3    Unnamed: 4  \
# 0         NaN                NaN              NaN        NaN           NaN
# 1          지역                 상호               주소         상표          전화번호
# 2       부산광역시  광신석유(주)직영 충렬대로주유소   부산 동래구 충렬대로 95      SK에너지  051-555-3258
# 3       부산광역시              대일주유소  부산 동래구 충렬대로 124      알뜰주유소  051-502-1155
# 4       부산광역시       ㈜OS에너지 동호주유소   부산 동래구 반송로 245      GS칼텍스  051-526-9967
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8   Unnamed: 9
# 0        NaN        NaN        NaN        NaN  (단위 : 원/리터)
# 1       셀프여부      고급휘발유        휘발유         경유         실내등유
# 2          Y       1919       1489       1349            -
# 3          Y          -       1499       1349            -
# 4          Y          -       1499       1349         1400
#
# --- DataFrame 6 ---
#   지역_위치별(주유소) Unnamed: 1              Unnamed: 2 Unnamed: 3    Unnamed: 4  \
# 0         NaN        NaN                     NaN        NaN           NaN
# 1          지역         상호                      주소         상표          전화번호
# 2       부산광역시   (주)태화주유소        부산 부산진구 가야대로 402      SK에너지  051-896-6147
# 3       부산광역시      대양주유소  부산 부산진구 새싹로 61-1 (부암동)      알뜰주유소  051-818-6161
# 4       부산광역시      진성주유소        부산 부산진구 백양대로 242      S-OIL  051-896-4500
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8   Unnamed: 9
# 0        NaN        NaN        NaN        NaN  (단위 : 원/리터)
# 1       셀프여부      고급휘발유        휘발유         경유         실내등유
# 2          Y          -       1559       1419            -
# 3          Y          -       1563       1423            -
# 4          Y          -       1569       1429            -
#
# --- DataFrame 7 ---
#   지역_위치별(주유소)         Unnamed: 1            Unnamed: 2 Unnamed: 3  \
# 0         NaN                NaN                   NaN        NaN
# 1          지역                 상호                    주소         상표
# 2       부산광역시          삼보주유소/충전소  부산 북구 만덕대로 331 (만덕동)      GS칼텍스
# 3       부산광역시     (주)삼보부림SELF주유소  부산 북구 만덕대로 343 (만덕동)      GS칼텍스
# 4       부산광역시  광신석유(주)직영 백양대로주유소  부산 북구 백양대로 995 (구포동)      SK에너지
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8   Unnamed: 9
# 0           NaN        NaN        NaN        NaN        NaN  (단위 : 원/리터)
# 1          전화번호       셀프여부      고급휘발유        휘발유         경유         실내등유
# 2  051-336-2002          Y       1919       1549       1399         1500
# 3  051-338-5156          Y          -       1549       1399            -
# 4  051-337-3100          Y          -       1559       1419            -
#
# --- DataFrame 8 ---
#   지역_위치별(주유소)         Unnamed: 1              Unnamed: 2 Unnamed: 3  \
# 0         NaN                NaN                     NaN        NaN
# 1          지역                 상호                      주소         상표
# 2       부산광역시   (주)가온에너지 더힘대로주유소  부산 사상구 낙동대로 1274 (삼락동)   HD현대오일뱅크
# 3       부산광역시  광신석유(주)직영 가야대로주유소         부산 사상구 가야대로 395      SK에너지
# 4       부산광역시      우리주유소 (주)시블링스   부산 사상구 백양대로 701 (덕포동)      알뜰주유소
#
#       Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8   Unnamed: 9
# 0            NaN        NaN        NaN        NaN        NaN  (단위 : 원/리터)
# 1           전화번호       셀프여부      고급휘발유        휘발유         경유         실내등유
# 2   051-305-9558          Y          -       1548       1398            -
# 3  070-4788-8153          Y       1919       1559       1419            -
# 4   051-304-3654          Y          -       1559       1419            -
#
# --- DataFrame 9 ---
#   지역_위치별(주유소)       Unnamed: 1            Unnamed: 2 Unnamed: 3    Unnamed: 4  \
# 0         NaN              NaN                   NaN        NaN           NaN
# 1          지역               상호                    주소         상표          전화번호
# 2       부산광역시         서부산농협주유소  부산 사하구 장평로 177 (장림동)     NH-OIL  051-262-0072
# 3       부산광역시          장림대흥주유소  부산 사하구 다대로 292 (장림동)      SK에너지  051-262-5189
# 4       부산광역시  새마당주유소 (주)지오에너지  부산 사하구 장평로 152 (장림동)      알뜰주유소  051-791-2632
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8   Unnamed: 9
# 0        NaN        NaN        NaN        NaN  (단위 : 원/리터)
# 1       셀프여부      고급휘발유        휘발유         경유         실내등유
# 2          Y          -       1559       1389            -
# 3          Y       1838       1569       1389            -
# 4          Y          -       1569       1389         1380
#
# --- DataFrame 10 ---
#   지역_위치별(주유소)           Unnamed: 1            Unnamed: 2 Unnamed: 3  \
# 0         NaN                  NaN                   NaN        NaN
# 1          지역                   상호                    주소         상표
# 2       부산광역시              남항대교주유소  부산 서구 충무대로 108 (암남동)      SK에너지
# 3       부산광역시           피치스주유소 빙고점        부산 서구 충무대로 240      S-OIL
# 4       부산광역시  충무대로 셀프주유소 와이케이에너지㈜        부산 서구 충무대로 126      GS칼텍스
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8   Unnamed: 9
# 0           NaN        NaN        NaN        NaN        NaN  (단위 : 원/리터)
# 1          전화번호       셀프여부      고급휘발유        휘발유         경유         실내등유
# 2  051-231-5145          Y          -       1528       1388         1450
# 3  051-242-7719          Y          -       1528       1388            -
# 4  051-242-5189          Y       1728       1528       1388            -
#
# --- DataFrame 11 ---
#   지역_위치별(주유소)       Unnamed: 1            Unnamed: 2 Unnamed: 3    Unnamed: 4  \
# 0         NaN              NaN                   NaN        NaN           NaN
# 1          지역               상호                    주소         상표          전화번호
# 2       부산광역시   (주)세왕에너지 세진주유소        부산 수영구 광남로 176      SK에너지  051-755-8188
# 3       부산광역시         마린타이거주유소  부산 수영구 광남로 241 (민락동)      GS칼텍스  051-756-0903
# 4       부산광역시  (주)경인에너지 광안리주유소         부산 수영구 광남로 83      S-OIL  051-754-9799
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8   Unnamed: 9
# 0        NaN        NaN        NaN        NaN  (단위 : 원/리터)
# 1       셀프여부      고급휘발유        휘발유         경유         실내등유
# 2          Y          -       1563       1433            -
# 3          Y          -       1563       1433            -
# 4          Y       1779       1563       1433            -
#
# --- DataFrame 12 ---
#   지역_위치별(주유소)        Unnamed: 1              Unnamed: 2 Unnamed: 3  \
# 0         NaN               NaN                     NaN        NaN
# 1          지역                상호                      주소         상표
# 2       부산광역시        하얀100연산주유소           부산 연제구 반송로 68      SK에너지
# 3       부산광역시           아시아드주유소  부산 연제구  거제대로 130 (거제동)      GS칼텍스
# 4       부산광역시  (주)좋은기름나라연산주유소지점     부산 연제구 고분로 51 (연산동)      S-OIL
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8   Unnamed: 9
# 0           NaN        NaN        NaN        NaN        NaN  (단위 : 원/리터)
# 1          전화번호       셀프여부      고급휘발유        휘발유         경유         실내등유
# 2  051-868-5252          Y          -       1549       1399            -
# 3  051-852-4144          Y       1813       1559       1419            -
# 4  051-851-5199          Y          -       1565       1425            -
#
# --- DataFrame 13 ---
#   지역_위치별(주유소) Unnamed: 1        Unnamed: 2 Unnamed: 3    Unnamed: 4  \
# 0         NaN        NaN               NaN        NaN           NaN
# 1          지역         상호                주소         상표          전화번호
# 2       부산광역시      동현주유소    부산 영도구 해양로 212      SK에너지  051-405-5170
# 3       부산광역시    해양특구주유소    부산 영도구 해양로 270      GS칼텍스  051-404-5189
# 4       부산광역시   태종대온천주유소  부산 영도구 태종로 806-1      SK에너지  051-405-2530
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8   Unnamed: 9
# 0        NaN        NaN        NaN        NaN  (단위 : 원/리터)
# 1       셀프여부      고급휘발유        휘발유         경유         실내등유
# 2          Y          -       1692       1572         1400
# 3          Y          -       1692       1572            -
# 4          N          -       1697       1577         1400
#
# --- DataFrame 14 ---
#   지역_위치별(주유소) Unnamed: 1             Unnamed: 2 Unnamed: 3    Unnamed: 4  \
# 0         NaN        NaN                    NaN        NaN           NaN
# 1          지역         상호                     주소         상표          전화번호
# 2       부산광역시      고려주유소  부산 중구 대청로 153 (중앙동5가)      SK에너지  051-469-1288
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8   Unnamed: 9
# 0        NaN        NaN        NaN        NaN  (단위 : 원/리터)
# 1       셀프여부      고급휘발유        휘발유         경유         실내등유
# 2          N          -       1695       1565         1350
#
# --- DataFrame 15 ---
#   지역_위치별(주유소)   Unnamed: 1         Unnamed: 2 Unnamed: 3    Unnamed: 4  \
# 0         NaN          NaN                NaN        NaN           NaN
# 1          지역           상호                 주소         상표          전화번호
# 2       부산광역시  ㈜영원석유 하늘주유소  부산 해운대구 해운대로 1184      GS칼텍스  051-704-0980
# 3       부산광역시       송정역주유소  부산 해운대구 해운대로 1217      S-OIL  051-717-3070
# 4       부산광역시  ㈜영원석유 영원주유소  부산 해운대구 해운대로 1178   HD현대오일뱅크  051-702-7293
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8   Unnamed: 9
# 0        NaN        NaN        NaN        NaN  (단위 : 원/리터)
# 1       셀프여부      고급휘발유        휘발유         경유         실내등유
# 2          Y          -       1519       1394            -
# 3          Y          -       1519       1374            -
# 4          Y       1839       1519       1374            -

# %%
import pandas as pd
import os
from glob import glob

folder_path = r"Downloads" 
all_files = glob(os.path.join(folder_path, "지역_위치별(주유소)*.xls"))

df_list = []

for file in all_files:
    try:
        df = pd.read_excel(file, skiprows=1)

        df = df[df.iloc[:, 0].notna()]  # 첫 번째 열 비어있지 않은 행만
        df = df[~df.iloc[:, 0].astype(str).str.contains("총")]

        df_list.append(df)

    except Exception as e:
        print(f"{file} 처리 중 오류: {e}")

combined_df = pd.concat(df_list, ignore_index=True)

print(combined_df.head())
print(f"총 {len(combined_df)}개 행으로 통합 완료")

combined_df.to_excel("부산_전체_주유소_통합.xlsx", index=False)
# Out:
#   Unnamed: 0       Unnamed: 1              Unnamed: 2 Unnamed: 3  \
# 0         지역               상호                      주소         상표
# 1      부산광역시  한길주유소 금사점 한솔유화㈜    부산 금정구 반송로 420 (금사동)   HD현대오일뱅크
# 2      부산광역시         훼미리알뜰주유소            부산 금정구 두실로 2      알뜰주유소
# 3      부산광역시       은마석유 노포주유소  부산 금정구 중앙대로 2191 (노포동)      GS칼텍스
# 4      부산광역시          청룡명품주유소        부산 금정구 중앙대로 2130   HD현대오일뱅크
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 (단위 : 원/리터)
# 0          전화번호       셀프여부      고급휘발유        휘발유         경유        실내등유
# 1  051-524-6642          Y       1897       1549       1419           -
# 2  051-582-5882          Y          -       1575       1437           -
# 3  051-508-1645          Y       1849       1575       1437        1350
# 4  051-508-5150          Y          -       1575       1437           -
# 총 363개 행으로 통합 완료

# %%
combined_df.columns = ['local','name','addr','mark','tel','self','oil1','oil2','oil3','oil4']
combined_df
# Out:
#      local             name                    addr      mark           tel  \
# 0       지역               상호                      주소        상표          전화번호
# 1    부산광역시  한길주유소 금사점 한솔유화㈜    부산 금정구 반송로 420 (금사동)  HD현대오일뱅크  051-524-6642
# 2    부산광역시         훼미리알뜰주유소            부산 금정구 두실로 2     알뜰주유소  051-582-5882
# 3    부산광역시       은마석유 노포주유소  부산 금정구 중앙대로 2191 (노포동)     GS칼텍스  051-508-1645
# 4    부산광역시          청룡명품주유소        부산 금정구 중앙대로 2130  HD현대오일뱅크  051-508-5150
# ..     ...              ...                     ...       ...           ...
# 358  부산광역시         (주)서호주유소    부산 강서구 명지국제2로28번길 36     S-OIL  051-206-6661
# 359  부산광역시            만선주유소    부산 강서구 가락대로210번길 102  HD현대오일뱅크  051-831-9171
# 360  부산광역시  비케이원(주) 미래드림주유소         부산 강서구 가락대로 649  HD현대오일뱅크  051-974-0808
# 361  부산광역시   대양산업(주)대양가덕주유소        부산 강서구 거가대로 2571     GS칼텍스  051-715-2201
# 362  부산광역시  광신석유(주)직영 명지주유소       부산 강서구 르노삼성대로 372     SK에너지  051-271-4405
#
#      self   oil1  oil2  oil3  oil4
# 0    셀프여부  고급휘발유   휘발유    경유  실내등유
# 1       Y   1897  1549  1419     -
# 2       Y      -  1575  1437     -
# 3       Y   1849  1575  1437  1350
# 4       Y      -  1575  1437     -
# ..    ...    ...   ...   ...   ...
# 358     Y   1998  1678  1518     -
# 359     N      -  1698  1558     -
# 360     Y      -  1709  1559     -
# 361     Y      -  1788  1638  1400
# 362     Y   1959  1899  1897  1799
#
# [363 rows x 10 columns]

# %%
combined_df = combined_df.drop(0).reset_index(drop=True)
combined_df
# Out:
#      local             name                     addr      mark           tel  \
# 0    부산광역시  한길주유소 금사점 한솔유화㈜     부산 금정구 반송로 420 (금사동)  HD현대오일뱅크  051-524-6642
# 1    부산광역시         훼미리알뜰주유소             부산 금정구 두실로 2     알뜰주유소  051-582-5882
# 2    부산광역시       은마석유 노포주유소   부산 금정구 중앙대로 2191 (노포동)     GS칼텍스  051-508-1645
# 3    부산광역시          청룡명품주유소         부산 금정구 중앙대로 2130  HD현대오일뱅크  051-508-5150
# 4    부산광역시          금두꺼비주유소  부산광역시 금정구  부곡로 67 (부곡동)     알뜰주유소  051-583-6433
# ..     ...              ...                      ...       ...           ...
# 357  부산광역시         (주)서호주유소     부산 강서구 명지국제2로28번길 36     S-OIL  051-206-6661
# 358  부산광역시            만선주유소     부산 강서구 가락대로210번길 102  HD현대오일뱅크  051-831-9171
# 359  부산광역시  비케이원(주) 미래드림주유소          부산 강서구 가락대로 649  HD현대오일뱅크  051-974-0808
# 360  부산광역시   대양산업(주)대양가덕주유소         부산 강서구 거가대로 2571     GS칼텍스  051-715-2201
# 361  부산광역시  광신석유(주)직영 명지주유소        부산 강서구 르노삼성대로 372     SK에너지  051-271-4405
#
#     self  oil1  oil2  oil3  oil4   구군
# 0      Y  1897  1549  1419     -  금정구
# 1      Y     -  1575  1437     -  금정구
# 2      Y  1849  1575  1437  1350  금정구
# 3      Y     -  1575  1437     -  금정구
# 4      Y     -  1587  1457     -  금정구
# ..   ...   ...   ...   ...   ...  ...
# 357    Y  1998  1678  1518     -  강서구
# 358    N     -  1698  1558     -  강서구
# 359    Y     -  1709  1559     -  강서구
# 360    Y     -  1788  1638  1400  강서구
# 361    Y  1959  1899  1897  1799  강서구
#
# [362 rows x 11 columns]

# %%
df1 = pd.read_csv('부산_전체_주유소_수정.csv')
c_data = df1.sort_values('휘발유', ascending=True).head(5)
e_data = df1.sort_values('휘발유', ascending=False).head(5)
df1
# Out:
#        구                      주소                 상호     휘발유      경유  \
# 0    강서구         부산 강서구 낙동남로 432              해안주유소  1549.0  1399.0
# 1    강서구   부산 강서구 낙동남로 127 (송정동)   신창에너지㈜직영 송정셀프주유소  1549.0  1409.0
# 2    강서구         부산 강서구 낙동북로 364        은마석유 경기장주유소  1557.0  1417.0
# 3    강서구  부산 강서구 낙동북로 209 (대저1동)      동방석유㈜직영 대저주유소  1557.0  1417.0
# 4    강서구         부산 강서구 낙동북로 142             우리2주유소  1557.0  1417.0
# ..   ...                     ...                ...     ...     ...
# 342  사상구        부산 사상구 낙동대로 1320              대림주유소  1679.0  1549.0
# 343  사상구         부산 사상구 낙동대로 935  광신홀딩스㈜ 직영 낙동대로주유소  1689.0  1544.0
# 344  사상구    부산 사상구 학감대로 73 (학장동)           행복한셀프주유소  1689.0  1549.0
# 345  사상구        부산 사상구 낙동대로 1380     지에스칼텍스(주)서부주유소  1739.0  1599.0
# 346  사상구    부산 사상구 새벽로 207 (괘법동)           아시아사상주유소  1797.0  1687.0
#
#             위도          경도
# 0    35.111787  128.867467
# 1    35.101886  128.836964
# 2    35.211911  128.968054
# 3    35.214206  128.951693
# 4    35.215329  128.944364
# ..         ...         ...
# 342  35.177934  128.976559
# 343  35.144005  128.969270
# 344  35.138868  128.991863
# 345  35.183325  128.976685
# 346  35.159733  128.983732
#
# [347 rows x 7 columns]

# %%
import folium

m = folium.Map(location=[35.1796, 129.0756], zoom_start=12)

for _, row in c_data.iterrows():
    popup_html = f"""
    <div style="font-size:13px;">
        <b>{row['상호']}</b><br>
        휘발유: {int(row['휘발유'])}원
    </div>
    """
    folium.Marker(
        location=[row['위도'], row['경도']],
        popup=folium.Popup(popup_html, max_width=200),
        icon=folium.Icon(color='blue')
    ).add_to(m)

for _, row in e_data.iterrows():
    popup_html = f"""
    <div style="font-size:13px;">
        <b>{row['상호']}</b><br>
        휘발유: {int(row['휘발유'])}원
    </div>
    """
    folium.Marker(
        location=[row['위도'], row['경도']],
        popup=folium.Popup(popup_html, max_width=200),
        icon=folium.Icon(color='red')
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0d989b844c2773bd126f0d46e9212e09 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0d989b844c2773bd126f0d46e9212e09&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0d989b844c2773bd126f0d46e9212e09 = L.map(
#                 &quot;map_0d989b844c2773bd126f0d46e9212e09&quot;,
#                 {
#                     center: [35.1796, 129.0756],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e891a7f8b46ba6eb3b66c1466e6d60a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9e891a7f8b46ba6eb3b66c1466e6d60a.addTo(map_0d989b844c2773bd126f0d46e9212e09);
#
#
#             var marker_318c483e95942abf1049769d9661242b = L.marker(
#                 [35.2074394, 129.0715907],
#                 {
# }
#             ).addTo(map_0d989b844c2773bd126f0d46e9212e09);
#
#
#             var icon_388f25f608ded0b0bcc552871341f0e9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2f3252da99afe9580e8313f01d8a78e1 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_79afacbd181c9b3780d83bb906faea58 = $(`&lt;div id=&quot;html_79afacbd181c9b3780d83bb906faea58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;div style=&quot;font-size:13px;&quot;&gt;         &lt;b&gt;광신석유(주)직영 충렬대로주유소&lt;/b&gt;&lt;br&gt;         휘발유: 1489원     &lt;/div&gt;     &lt;/div&gt;`)[0];
#                 popup_2f3252da99afe9580e8313f01d8a78e1.setContent(html_79afacbd181c9b3780d83bb906faea58);
#
#
#
#         marker_318c483e95942abf1049769d9661242b.bindPopup(popup_2f3252da99afe9580e8313f01d8a78e1)
#         ;
#
#
#
#
#                 marker_318c483e95942abf1049769d9661242b.setIcon(icon_388f25f608ded0b0bcc552871341f0e9);
#
#
#             var marker_53389ab7b20c4917fe748f57d174d133 = L.marker(
#                 [35.2058571, 129.0738774],
#                 {
# }
#             ).addTo(map_0d989b844c2773bd126f0d46e9212e09);
#
#
#             var icon_c1bc705dac69edb7a56d1c0662fe857d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_5c441be0516254b702b68bbf67a8b571 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_31d7a1834c02c6041037459bf3d4a494 = $(`&lt;div id=&quot;html_31d7a1834c02c6041037459bf3d4a494&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;div style=&quot;font-size:13px;&quot;&gt;         &lt;b&gt;대일주유소&lt;/b&gt;&lt;br&gt;         휘발유: 1499원     &lt;/div&gt;     &lt;/div&gt;`)[0];
#                 popup_5c441be0516254b702b68bbf67a8b571.setContent(html_31d7a1834c02c6041037459bf3d4a494);
#
#
#
#         marker_53389ab7b20c4917fe748f57d174d133.bindPopup(popup_5c441be0516254b702b68bbf67a8b571)
#         ;
#
#
#
#
#                 marker_53389ab7b20c4917fe748f57d174d133.setIcon(icon_c1bc705dac69edb7a56d1c0662fe857d);
#
#
#             var marker_9c2e880bb18d4e6315b0efb7d0368f8c = L.marker(
#                 [35.2064321, 129.0739197],
#                 {
# }
#             ).addTo(map_0d989b844c2773bd126f0d46e9212e09);
#
#
#             var icon_2a26567d4d39d3bd509d79be0dcd1be7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b9eb8c1bb3a30ee9d0d8a69c3cea058f = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_a73d2fc160f781c903551f1851d97290 = $(`&lt;div id=&quot;html_a73d2fc160f781c903551f1851d97290&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;div style=&quot;font-size:13px;&quot;&gt;         &lt;b&gt;동방석유(주)푸른주유소&lt;/b&gt;&lt;br&gt;         휘발유: 1499원     &lt;/div&gt;     &lt;/div&gt;`)[0];
#                 popup_b9eb8c1bb3a30ee9d0d8a69c3cea058f.setContent(html_a73d2fc160f781c903551f1851d97290);
#
#
#
#         marker_9c2e880bb18d4e6315b0efb7d0368f8c.bindPopup(popup_b9eb8c1bb3a30ee9d0d8a69c3cea058f)
#         ;
#
#
#
#
#                 marker_9c2e880bb18d4e6315b0efb7d0368
